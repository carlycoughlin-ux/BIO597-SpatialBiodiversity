# %% [markdown]
# # Assignment 02: Fetching Occurrence Records With pygbif
#
# ## BIO597 Spatial Analysis of Biodiversity
#
# This assignment gives you more practice with the workflow from Lab 02.
#
# You will use `pygbif` to search GBIF for several snake species, download a small number of occurrence records, convert those records to `GeoDataFrame` objects, and make simple maps and summaries.
#
# Some cells are partly filled in. You should fill in the missing pieces and run the notebook from top to bottom.
#
# Remember, learning to code is often about learning how to strategically copy, paste, and modify. Look back at Lab 02 when you need a model.

# %% [markdown]
# ## Species for this assignment
#
# Use these species:
#
# * *Storeria dekayi*
# * *Agkistrodon contortrix*
# * *Pantherophis guttatus*
# * one additional snake species of your choice
#     I chose Farancia abacura
#
# For each species, we will ask GBIF for georeferenced records so the results can be mapped.

# %% [markdown]
# ## 1. Import packages
#
# Import the same packages used in Lab 02.
#
# `species` is used for taxonomic name searches. `occ` is used for occurrence record searches.

# %%
from pygbif import species
from pygbif import occurrences as occ

import pandas as pd
import geopandas as gpd

# %% [markdown]
# ## 2. Search for possible name matches
#
# Use `species.name_suggest()` to search for *Storeria dekayi*.
#
# Fill in the species name. Then inspect the first result.

# %%
dekayi_suggestions = species.name_suggest(q="Storeria dekay")
# dekayi_suggestions will have a list of dictionaries
# select the first element of this list here and save it as a new variable called `dekayi_match`
dekayi_match = dekayi_suggestions[0]

dekayi_match
# Out:
# {'key': 9056579,
#  'nameKey': 10782717,
#  'kingdom': 'Animalia',
#  'phylum': 'Chordata',
#  'family': 'Colubridae',
#  'genus': 'Storeria',
#  'species': 'Storeria dekayi',
#  'kingdomKey': 1,
#  'phylumKey': 44,
#  'classKey': 11592253,
#  'familyKey': 6172,
#  'genusKey': 9213370,
#  'speciesKey': 9056579,
#  'parent': 'Storeria',
#  'parentKey': 9213370,
#  'nubKey': 9056579,
#  'scientificName': 'Storeria dekayi (Holbrook, 1839)',
#  'canonicalName': 'Storeria dekayi',
#  'rank': 'SPECIES',
#  'status': 'ACCEPTED',
#  'synonym': False,
#  'higherClassificationMap': {'1': 'Animalia',
#   '44': 'Chordata',
#   '11592253': 'Squamata',
#   '6172': 'Colubridae',
#   '9213370': 'Storeria'},
#  'class': 'Squamata'}

# %% [markdown]
# ## 3. Save the taxon key
#
# Pull the `speciesKey` out of the match result and save it as `dekayi_key`.

# %%
dekayi_key = dekayi_match["speciesKey"]
dekayi_key
# Out:
# 9056579

# %% [markdown]
# ## 4. Count records before downloading
#
# Use `occ.count()` to count georeferenced GBIF records for *Storeria dekayi*.
#
# This count tells you how many records GBIF has that match your search, not how many you will download in this assignment.

# %%
dekayi_count = occ.count(
    taxonKey=dekayi_key,
    isGeoreferenced=True,
)

dekayi_count
# Out:
# 49474

# %% [markdown]
# ## 5. Determine how many _total_ records there are for S. dekayi
#
# ## 5. Determine how many _total_ records there are for S. dekayi
#
# The `isGeoreferenced` parameter determines whether occurrences with latlongs are returned.
# Make a copy of the call to `occ.count()` as above, but change the `True` to `False`, which
# will return only occurrences **without** latlongs. Capture the results in a new variable
# called `dekayi_nolatlong_count` and then add this to `dekayi_count` from the previous cell
# to get the total number of records.

# %%
# How many total S. Dekayi records are there?
dekayi_nolatlong_count = occ.count(
    taxonKey=dekayi_key,
    isGeoreferenced=False,
)

print (dekayi_count)
print (dekayi_nolatlong_count)
print (dekayi_count + dekayi_nolatlong_count)
# Out:
# 49474
# 7073
# 56547

# %% [markdown]
# ## 6. Fetch up to 100 records
#
# Use `occ.search()` to fetch occurrence records for *Storeria dekayi*.
#
# Keep `limit=100`. Do not request more than 100 records for a species in this assignment.

# %%
dekayi_records = occ.search(
    speciesKey=9056579,
    hasCoordinate=True,
    hasGeospatialIssue=False,
    limit=100,
)

dekayi_records.keys()
# Out:
# dict_keys(['offset', 'limit', 'endOfRecords', 'count', 'results', 'facets'])

# %% [markdown]
# ## 7. Turn the records into a table
#
# The occurrence records are stored in the "results" key of the `dekayi_records` dictionary. Convert that list of records to a pandas DataFrame.

# %%
dekayi_df = pd.DataFrame(dekayi_records["results"])
dekayi_df.head()
# Out:
#           key                            datasetKey  \
# 0  5938064620  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 1  5938201753  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 2  5938457152  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 3  5938490464  50c9509d-22c7-4a22-a47d-8c48425ef4a7
# 4  5938606080  50c9509d-22c7-4a22-a47d-8c48425ef4a7
#
#                        publishingOrgKey   datasetCategory  \
# 0  28eb1a3f-1c15-4a95-931a-4af90ecb574d  [CitizenScience]
# 1  28eb1a3f-1c15-4a95-931a-4af90ecb574d  [CitizenScience]
# 2  28eb1a3f-1c15-4a95-931a-4af90ecb574d  [CitizenScience]
# 3  28eb1a3f-1c15-4a95-931a-4af90ecb574d  [CitizenScience]
# 4  28eb1a3f-1c15-4a95-931a-4af90ecb574d  [CitizenScience]
#
#                         installationKey                hostingOrganizationKey  \
# 0  997448a8-f762-11e1-a439-00145eb45e9a  28eb1a3f-1c15-4a95-931a-4af90ecb574d
# 1  997448a8-f762-11e1-a439-00145eb45e9a  28eb1a3f-1c15-4a95-931a-4af90ecb574d
# 2  997448a8-f762-11e1-a439-00145eb45e9a  28eb1a3f-1c15-4a95-931a-4af90ecb574d
# 3  997448a8-f762-11e1-a439-00145eb45e9a  28eb1a3f-1c15-4a95-931a-4af90ecb574d
# 4  997448a8-f762-11e1-a439-00145eb45e9a  28eb1a3f-1c15-4a95-931a-4af90ecb574d
#
#   publishingCountry     protocol                    lastCrawled  \
# 0                US  DWC_ARCHIVE  2026-09-10T19:15:51.157+00:00
# 1                US  DWC_ARCHIVE  2026-09-10T19:15:51.157+00:00
# 2                US  DWC_ARCHIVE  2026-09-10T19:15:51.157+00:00
# 3                US  DWC_ARCHIVE  2026-09-10T19:15:51.157+00:00
# 4                US  DWC_ARCHIVE  2026-09-10T19:15:51.157+00:00
#
#                       lastParsed  ...       eventTime identificationID  \
# 0  2026-09-11T05:22:11.912+00:00  ...  16:48:33-06:00        745332273
# 1  2026-09-11T05:48:03.041+00:00  ...  14:41:00-06:00        746093157
# 2  2026-09-11T05:36:08.412+00:00  ...  04:52:51-06:00        745694353
# 3  2026-09-11T05:51:42.840+00:00  ...  14:00:00-05:00        746922821
# 4  2026-09-11T05:22:15.726+00:00  ...  11:27:14-06:00        745678895
#
#              occurrenceRemarks  \
# 0                          NaN
# 1      Body about 0.5 cm wide.
# 2                          NaN
# 3  First snake of the year !!!
# 4                          NaN
#
#                                  informationWithheld projectId  \
# 0                                                NaN       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3  Coordinate uncertainty increased to 28734m at ...       NaN
# 4                                                NaN       NaN
#
#    dynamicProperties  vitality  lifeStage  identificationRemarks  sex
# 0                NaN       NaN        NaN                    NaN  NaN
# 1                NaN       NaN        NaN                    NaN  NaN
# 2                NaN       NaN        NaN                    NaN  NaN
# 3                NaN       NaN        NaN                    NaN  NaN
# 4                NaN       NaN        NaN                    NaN  NaN
#
# [5 rows x 97 columns]

# %% [markdown]
# ## 8. Keep a small set of useful columns
#
# Keep the columns needed for a map and a few simple summaries.
#
# Fill in the latitude column name.

# %%
dekayi_small = dekayi_df[
    ["key", "scientificName", "decimalLongitude", "decimalLatitude", "year", "basisOfRecord", "countryCode"]
]

dekayi_small.head()
# Out:
#           key                    scientificName  decimalLongitude  \
# 0  5938064620  Storeria dekayi (Holbrook, 1839)        -97.122430
# 1  5938201753  Storeria dekayi (Holbrook, 1839)        -92.908814
# 2  5938457152  Storeria dekayi (Holbrook, 1839)        -86.721496
# 3  5938490464  Storeria dekayi (Holbrook, 1839)        -80.744301
# 4  5938606080  Storeria dekayi (Holbrook, 1839)        -97.508688
#
#    decimalLatitude  year      basisOfRecord countryCode
# 0        33.241408  2026  HUMAN_OBSERVATION          US
# 1        34.619900  2026  HUMAN_OBSERVATION          US
# 2        33.458035  2026  HUMAN_OBSERVATION          US
# 3        35.172939  2026  HUMAN_OBSERVATION          US
# 4        35.238997  2026  HUMAN_OBSERVATION          US

# %% [markdown]
# ## 9. Convert the table to a GeoDataFrame
#
# Use the longitude and latitude columns to create point geometry. This is the same idea as Lab 01 and Lab 02.

# %%
dekayi_gdf = gpd.GeoDataFrame(
    dekayi_small,
    geometry=gpd.points_from_xy(dekayi_small["decimalLongitude"], dekayi_small["decimalLatitude"]),
    crs="EPSG:4326",
)

dekayi_gdf["Species"] = "Storeria dekayi"
dekayi_gdf.head()
# Out:
#           key                    scientificName  decimalLongitude  \
# 0  5938064620  Storeria dekayi (Holbrook, 1839)        -97.122430
# 1  5938201753  Storeria dekayi (Holbrook, 1839)        -92.908814
# 2  5938457152  Storeria dekayi (Holbrook, 1839)        -86.721496
# 3  5938490464  Storeria dekayi (Holbrook, 1839)        -80.744301
# 4  5938606080  Storeria dekayi (Holbrook, 1839)        -97.508688
#
#    decimalLatitude  year      basisOfRecord countryCode  \
# 0        33.241408  2026  HUMAN_OBSERVATION          US
# 1        34.619900  2026  HUMAN_OBSERVATION          US
# 2        33.458035  2026  HUMAN_OBSERVATION          US
# 3        35.172939  2026  HUMAN_OBSERVATION          US
# 4        35.238997  2026  HUMAN_OBSERVATION          US
#
#                      geometry          Species
# 0  POINT (-97.12243 33.24141)  Storeria dekayi
# 1   POINT (-92.90881 34.6199)  Storeria dekayi
# 2   POINT (-86.7215 33.45804)  Storeria dekayi
# 3   POINT (-80.7443 35.17294)  Storeria dekayi
# 4    POINT (-97.50869 35.239)  Storeria dekayi

# %% [markdown]
# ## 10. Map *Storeria dekayi*
#
# Make an interactive map of the *Storeria dekayi* records.

# %%
dekayi_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e6987b1f30c8422cd81cda99ca5cd3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e6987b1f30c8422cd81cda99ca5cd3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e6987b1f30c8422cd81cda99ca5cd3f = L.map(
#                 &quot;map_0e6987b1f30c8422cd81cda99ca5cd3f&quot;,
#                 {
#                     center: [33.9734105, -86.7033295],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_0e6987b1f30c8422cd81cda99ca5cd3f);
#
#
#
#
#
#             var tile_layer_0f7812e74182984f72f0e74f352e4fb7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f7812e74182984f72f0e74f352e4fb7.addTo(map_0e6987b1f30c8422cd81cda99ca5cd3f);
#
#
#             map_0e6987b1f30c8422cd81cda99ca5cd3f.fitBounds(
#                 [[25.771463, -98.225659], [42.175358, -75.181]],
#                 {}
#             );
#
#
#         function geo_json_2c375cae66debd6b75bfee62b0ea48cc_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_2c375cae66debd6b75bfee62b0ea48cc_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_2c375cae66debd6b75bfee62b0ea48cc_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_2c375cae66debd6b75bfee62b0ea48cc_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_2c375cae66debd6b75bfee62b0ea48cc_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_2c375cae66debd6b75bfee62b0ea48cc.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_2c375cae66debd6b75bfee62b0ea48cc_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_2c375cae66debd6b75bfee62b0ea48cc = L.geoJson(null, {
#                 onEachFeature: geo_json_2c375cae66debd6b75bfee62b0ea48cc_onEachFeature,
#
#                 style: geo_json_2c375cae66debd6b75bfee62b0ea48cc_styler,
#                 pointToLayer: geo_json_2c375cae66debd6b75bfee62b0ea48cc_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_2c375cae66debd6b75bfee62b0ea48cc_add (data) {
#             geo_json_2c375cae66debd6b75bfee62b0ea48cc
#                 .addData(data);
#         }
#             geo_json_2c375cae66debd6b75bfee62b0ea48cc_add({&quot;bbox&quot;: [-98.225659, 25.771463, -75.181, 42.175358], &quot;features&quot;: [{&quot;bbox&quot;: [-97.12243, 33.241408, -97.12243, 33.241408], &quot;geometry&quot;: {&quot;coordinates&quot;: [-97.12243, 33.241408], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Species&quot;: &quot;Storeria dekayi&quot;, &quot;basisOfRecord&quot;: &quot;HUMAN_OBSERVATION&quot;, &quot;countryCode&quot;: &quot;US&quot;, &quot;decimalLatitude

# %% [markdown]
# ## 11. Repeat the workflow for *Agkistrodon contortrix*
#
# Now repeat the same steps for eastern copperhead, *Agkistrodon contortrix*.
#
# This cell should get the name suggestions and save the speciesKey.

# %%
contortrix_suggestions = species.name_suggest(q="Agkistrodon contortrix")

# Select the first element from the `contortrix_suggestions` list
contortrix_match = contortrix_suggestions [0]

# Get the `speciesKey`
contortrix_key = contortrix_match["speciesKey"]

contortrix_key
# Out:
# 9215881

# %% [markdown]
# ## 13. Fetch and map *Agkistrodon contortrix*
#
# Write code to fetch up to 100 records with coordinates, convert them to a table, convert that table to a GeoDataFrame, add a `Species` column, and map the result.
#
# Use the same variable names shown in the comments. In `occ.search()`, use `hasCoordinate=True` and `hasGeospatialIssue=False`.

# %%
# Create contortrix_records with occ.search().
#count records
contortrix_count = occ.count(
    taxonKey=contortrix_key,
    isGeoreferenced=True,
)

contortrix_nolatlong_count = occ.count(
    taxonKey=contortrix_key,
    isGeoreferenced=False,
)

print (contortrix_count)
print (contortrix_nolatlong_count)
print (contortrix_count + contortrix_nolatlong_count)

#fetch records
contortrix_records = occ.search(
    speciesKey=9215881,
    hasCoordinate=True,
    hasGeospatialIssue=False,
    limit=100,
)

# Create contortrix_df from contortrix_records["results"].
contortrix_df = pd.DataFrame(contortrix_records["results"])

# Create contortrix_small with the columns you want to keep.
contortrix_small = contortrix_df[
    ["key", "scientificName", "decimalLongitude", "decimalLatitude", "year", "basisOfRecord", "countryCode"]
]

# Create contortrix_gdf with gpd.GeoDataFrame().
contortrix_gdf = gpd.GeoDataFrame(
    contortrix_small,
    geometry=gpd.points_from_xy(contortrix_small["decimalLongitude"], contortrix_small["decimalLatitude"]),
    crs="EPSG:4326",
)

# Add a Species column with the name Agkistrodon contortrix.
contortrix_gdf["Species"] = "Agkistrodon contortrix"

# Map contortrix_gdf with .explore().
contortrix_gdf.explore()
# Out:
# 23303
# 5812
# 29115
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_950374da3a903323ef705dbea120507e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_950374da3a903323ef705dbea120507e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_950374da3a903323ef705dbea120507e = L.map(
#                 &quot;map_950374da3a903323ef705dbea120507e&quot;,
#                 {
#                     center: [34.2329345, -86.462903],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_950374da3a903323ef705dbea120507e);
#
#
#
#
#
#             var tile_layer_01221221a3de6eb51ed9a617791c9cbd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_01221221a3de6eb51ed9a617791c9cbd.addTo(map_950374da3a903323ef705dbea120507e);
#
#
#             map_950374da3a903323ef705dbea120507e.fitBounds(
#                 [[29.044931, -96.907489], [39.420938, -76.018317]],
#                 {}
#             );
#
#
#         function geo_json_5652c7214a8f3cec6916f317e346e92f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5652c7214a8f3cec6916f317e346e92f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5652c7214a8f3cec6916f317e346e92f_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_5652c7214a8f3cec6916f317e346e92f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5652c7214a8f3cec6916f317e346e92f_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_5652c7214a8f3cec6916f317e346e92f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5652c7214a8f3cec6916f317e346e92f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5652c7214a8f3cec6916f317e346e92f = L.geoJson(null, {
#                 onEachFeature: geo_json_5652c7214a8f3cec6916f317e346e92f_onEachFeature,
#
#                 style: geo_json_5652c7214a8f3cec6916f317e346e92f_styler,
#                 pointToLayer: geo_json_5652c7214a8f3cec6916f317e346e92f_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_5652c7214a8f3cec6916f317e346e92f_add (data) {
#             geo_json_5652c7214a8f3cec6916f317e346e92f
#                 .addData(data);
#         }
#             geo_json_5652c7214a8f3cec6916f317e346e92f_add({&quot;bbox&quot;: [-96.907489, 29.044931, -76.018317, 39.420938], &quot;features&quot;: [{&quot;bbox&quot;: [-95.389135, 34.95654, -95.389135, 34.95654], &quot;geometry&quot;: {&quot;coordinates&quot;: [-95.389135, 34.95654], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Species&quot;: &quot;Agkistrodon contortrix&quot;, &quot;basisOfRecord&quot;: &quot;HUMAN_OBSERVATION&quot;, &quot;countryCode&quot;: &quot;US&quot;, &quot;dec

# %% [markdown]
# ## 14. Repeat the workflow for *Pantherophis guttatus*
#
# This time you will do a little more on your own.
#
# First, use `species.name_suggest()` to get the `speciesKey` for *Pantherophis guttatus*.

# %%
# Write your code here.
guttatus_suggestions = species.name_suggest(q="Pantherophis guttatus")

# Select the first element from the `contortrix_suggestions` list
guttatus_match = guttatus_suggestions [0]

# Get the `speciesKey`
guttatus_key = guttatus_match["speciesKey"]

guttatus_key
# Out:
# 2455615

# %% [markdown]
# ## 16. Fetch and map *Pantherophis guttatus*
#
# Fetch up to 100 georeferenced records and convert them to a GeoDataFrame.
#
# Keep the cell simple. It is fine to copy and modify code from earlier cells.

# %%
# Write your code here.


#count georeferenced records 
guttatus_count = occ.count(
    taxonKey=guttatus_key,
    isGeoreferenced=True,
)

guttatus_nolatlong_count = occ.count(
    taxonKey=guttatus_key,
    isGeoreferenced=False,
)
print (guttatus_count)
print (guttatus_nolatlong_count)
print (guttatus_count + guttatus_nolatlong_count)
guttatus_records = occ.search(
    speciesKey=2455615,
    hasCoordinate=True,
    hasGeospatialIssue=False,
    limit=100,
)

guttatus_df = pd.DataFrame(guttatus_records["results"])

guttatus_small = guttatus_df[
    ["key", "scientificName", "decimalLongitude", "decimalLatitude", "year", "basisOfRecord", "countryCode"]
]
guttatus_gdf = gpd.GeoDataFrame(
   guttatus_small,
    geometry=gpd.points_from_xy(guttatus_small["decimalLongitude"], guttatus_small["decimalLatitude"]),
    crs="EPSG:4326",
)
guttatus_gdf["Species"] = "Pantherophis guttatus"
guttatus_gdf.explore()
# Out:
# 10142
# 3072
# 13214
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65738d6ff6651189e7a34507e09fc955 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65738d6ff6651189e7a34507e09fc955&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65738d6ff6651189e7a34507e09fc955 = L.map(
#                 &quot;map_65738d6ff6651189e7a34507e09fc955&quot;,
#                 {
#                     center: [28.501316, -85.070773],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_65738d6ff6651189e7a34507e09fc955);
#
#
#
#
#
#             var tile_layer_2fd26567d6b03428b3e45b430c110979 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2fd26567d6b03428b3e45b430c110979.addTo(map_65738d6ff6651189e7a34507e09fc955);
#
#
#             map_65738d6ff6651189e7a34507e09fc955.fitBounds(
#                 [[24.67879, -89.967496], [32.323842, -80.17405]],
#                 {}
#             );
#
#
#         function geo_json_ecfcb36c5392fe16302fff06440c7174_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_ecfcb36c5392fe16302fff06440c7174_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_ecfcb36c5392fe16302fff06440c7174_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_ecfcb36c5392fe16302fff06440c7174_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_ecfcb36c5392fe16302fff06440c7174_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_ecfcb36c5392fe16302fff06440c7174.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_ecfcb36c5392fe16302fff06440c7174_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_ecfcb36c5392fe16302fff06440c7174 = L.geoJson(null, {
#                 onEachFeature: geo_json_ecfcb36c5392fe16302fff06440c7174_onEachFeature,
#
#                 style: geo_json_ecfcb36c5392fe16302fff06440c7174_styler,
#                 pointToLayer: geo_json_ecfcb36c5392fe16302fff06440c7174_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_ecfcb36c5392fe16302fff06440c7174_add (data) {
#             geo_json_ecfcb36c5392fe16302fff06440c7174
#                 .addData(data);
#         }
#             geo_json_ecfcb36c5392fe16302fff06440c7174_add({&quot;bbox&quot;: [-89.967496, 24.67879, -80.17405, 32.323842], &quot;features&quot;: [{&quot;bbox&quot;: [-81.394973, 30.135123, -81.394973, 30.135123], &quot;geometry&quot;: {&quot;coordinates&quot;: [-81.394973, 30.135123], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Species&quot;: &quot;Pantherophis guttatus&quot;, &quot;basisOfRecord&quot;: &quot;HUMAN_OBSERVATION&quot;, &quot;countryCode&quot;: &quot;US&quot;, &quot;decima

# %% [markdown]
# ## 17. Combine the three GeoDataFrames
#
# Use `pd.concat()` to combine your three species GeoDataFrames.
#
# Then inspect the first few rows.

# %%
gbif_snakes = pd.concat([dekayi_gdf, contortrix_gdf, guttatus_gdf])

gbif_snakes.head()
# Out:
#           key                    scientificName  decimalLongitude  \
# 0  5938064620  Storeria dekayi (Holbrook, 1839)        -97.122430
# 1  5938201753  Storeria dekayi (Holbrook, 1839)        -92.908814
# 2  5938457152  Storeria dekayi (Holbrook, 1839)        -86.721496
# 3  5938490464  Storeria dekayi (Holbrook, 1839)        -80.744301
# 4  5938606080  Storeria dekayi (Holbrook, 1839)        -97.508688
#
#    decimalLatitude  year      basisOfRecord countryCode  \
# 0        33.241408  2026  HUMAN_OBSERVATION          US
# 1        34.619900  2026  HUMAN_OBSERVATION          US
# 2        33.458035  2026  HUMAN_OBSERVATION          US
# 3        35.172939  2026  HUMAN_OBSERVATION          US
# 4        35.238997  2026  HUMAN_OBSERVATION          US
#
#                      geometry          Species
# 0  POINT (-97.12243 33.24141)  Storeria dekayi
# 1   POINT (-92.90881 34.6199)  Storeria dekayi
# 2   POINT (-86.7215 33.45804)  Storeria dekayi
# 3   POINT (-80.7443 35.17294)  Storeria dekayi
# 4    POINT (-97.50869 35.239)  Storeria dekayi

# %% [markdown]
# ## 18. Map all three species together
#
# Use `.explore()` and color by `Species` so you can compare the three species on one map.

# %%
gbif_snakes.explore(column="Species", cmap="rainbow")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8711ba5d298e38796834ea28ac6de65d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend Species&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;Species&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8000ff&#x27;&gt;&lt;/span&gt;Agkistrodon contortrix&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#80ffb4&#x27;&gt;&lt;/span&gt;Pantherophis guttatus&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff0000&#x27;&gt;&lt;/span&gt;Storeria dekayi&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8711ba5d298e38796834ea28ac6de65d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8711ba5d298e38796834ea28ac6de65d = L.map(
#                 &quot;map_8711ba5d298e38796834ea28ac6de65d&quot;,
#                 {
#                     center: [33.427074000000005, -86.7033295],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_8711ba5d298e38796834ea28ac6de65d);
#
#
#
#
#
#             var tile_layer_615f227984bd1ec1fdc7b926841c7180 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_615f227984bd1ec1fdc7b926841c7180.addTo(map_8711ba5d298e38796834ea28ac6de65d);
#
#
#             map_8711ba5d298e38796834ea28ac6de65d.fitBounds(
#                 [[24.67879, -98.225659], [42.175358, -75.181]],
#                 {}
#             );
#
#
#         function geo_json_6862b7d1e84964e3594cdbf9d6204da8_styler(feature) {
#             switch(feature.properties.key) {
#                 case 5938064620: case 5938201753: case 5938457152: case 5938490464: case 5938606080: case 6129828857: case 6129864938: case 6129904709: case 6129921897: case 6129965968: case 6129983775: case 6130091856: case 6130124827: case 6130148178: case 6130247341: case 6130304884: case 6130342642: case 6130453870: case 6130517946: case 6130541399: case 6130567019: case 6130607433: case 6130611744: case 6130614257: case 6130697998: case 6130721887: case 6130758986: case 6130924555: case 6130951261: case 6131124564: case 6131166755: case 6131213399: case 6131316767: case 6131334432: case 6131399070: case 613

# %% [markdown]
# ## 19. Count records by species
#
# Use `groupby()` to count how many records you downloaded for each species.

# %%
gbif_snakes.groupby("Species").size()
# Out:
# Species
# Agkistrodon contortrix    100
# Pantherophis guttatus     100
# Storeria dekayi           100
# dtype: int64

# %% [markdown]
# ## 20. Count records by basis of record
#
# The `countryCode` field describes the general type of occurrence record.
#
# Use `groupby()` to count records by `countryCode`.

# %%
gbif_snakes.groupby("countryCode").size()
# Out:
# countryCode
# MX      2
# US    298
# dtype: int64

# %% [markdown]
# ## 21. Choose one additional species
#
# Choose one additional snake species and repeat the workflow.
#
# Your species does not have to be in the local `EasternSnakes` CSV files. It only needs to be a snake species that GBIF can find.
#
# Your code should:
#
# * use `species.name_suggest()`
# * save the taxon key
# * count georeferenced records
# * fetch no more than 100 records with `occ.search()`
# * convert the records to a `GeoDataFrame`
# * map the records

# %%
# Get Species Key for Micruroides euryxanthus the western coral snake
euryxanthus_suggestions = species.name_suggest(q="Micruroides euryxanthus")

euryxanthus_match = euryxanthus_suggestions [0]
euryxanthus_key = euryxanthus_match["speciesKey"]
euryxanthus_key
# Out:
# 2470302

# %%
#count georeferenced records for Micruroides euryxanthus
euryxanthus_count = occ.count(
    taxonKey=euryxanthus_key,
    isGeoreferenced=True,
)

euryxanthus_nolatlong_count = occ.count(
    taxonKey=euryxanthus_key,
    isGeoreferenced=False,
)
print (euryxanthus_count)
print (euryxanthus_nolatlong_count)
print (euryxanthus_count + euryxanthus_nolatlong_count)
# Out:
# 943
# 252
# 1195

# %%
#fetch no more than 100 records with occ.search()
euryxanthus_records = occ.search(
    speciesKey=2470302,
    hasCoordinate=True,
    hasGeospatialIssue=False,
    limit=100,
)
#convert the records to a GeoDataFrame
euryxanthus_df = pd.DataFrame(euryxanthus_records["results"])

euryxanthus_small = euryxanthus_df[
    ["key", "scientificName", "decimalLongitude", "decimalLatitude", "year", "basisOfRecord", "countryCode"]
]
euryxanthus_gdf = gpd.GeoDataFrame(
   euryxanthus_small,
    geometry=gpd.points_from_xy(euryxanthus_small["decimalLongitude"], euryxanthus_small["decimalLatitude"]),
    crs="EPSG:4326",
)
euryxanthus_gdf["Species"] = "Micruroides euryxanthus"
euryxanthus_gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5dfa4b59b1e5c1769ad1cd91abc7aad5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5dfa4b59b1e5c1769ad1cd91abc7aad5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5dfa4b59b1e5c1769ad1cd91abc7aad5 = L.map(
#                 &quot;map_5dfa4b59b1e5c1769ad1cd91abc7aad5&quot;,
#                 {
#                     center: [29.569249, -109.742976],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_5dfa4b59b1e5c1769ad1cd91abc7aad5);
#
#
#
#
#
#             var tile_layer_667657086d973eec96b7c23d7884d6d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_667657086d973eec96b7c23d7884d6d5.addTo(map_5dfa4b59b1e5c1769ad1cd91abc7aad5);
#
#
#             map_5dfa4b59b1e5c1769ad1cd91abc7aad5.fitBounds(
#                 [[25.14899, -112.686071], [33.989508, -106.799881]],
#                 {}
#             );
#
#
#         function geo_json_19741cd0e1d6945b92e37eb409502f32_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_19741cd0e1d6945b92e37eb409502f32_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_19741cd0e1d6945b92e37eb409502f32_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_19741cd0e1d6945b92e37eb409502f32_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_19741cd0e1d6945b92e37eb409502f32_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_19741cd0e1d6945b92e37eb409502f32.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_19741cd0e1d6945b92e37eb409502f32_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_19741cd0e1d6945b92e37eb409502f32 = L.geoJson(null, {
#                 onEachFeature: geo_json_19741cd0e1d6945b92e37eb409502f32_onEachFeature,
#
#                 style: geo_json_19741cd0e1d6945b92e37eb409502f32_styler,
#                 pointToLayer: geo_json_19741cd0e1d6945b92e37eb409502f32_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_19741cd0e1d6945b92e37eb409502f32_add (data) {
#             geo_json_19741cd0e1d6945b92e37eb409502f32
#                 .addData(data);
#         }
#             geo_json_19741cd0e1d6945b92e37eb409502f32_add({&quot;bbox&quot;: [-112.686071, 25.14899, -106.799881, 33.989508], &quot;features&quot;: [{&quot;bbox&quot;: [-111.007662, 32.403824, -111.007662, 32.403824], &quot;geometry&quot;: {&quot;coordinates&quot;: [-111.007662, 32.403824], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;Species&quot;: &quot;Micruroides euryxanthus&quot;, &quot;basisOfRecord&quot;: &quot;HUMAN_OBSERVATION&quot;, &quot;countryCode&quot;: &quot;US&quot;,

# %% [markdown]
# ## 22. Written reflection
#
# Answer these questions after running your code.
#
# **Question 1:** Which of your species had the most GBIF records available?
#
# **Your answer:** S. dekayi
#
# **Question 2:** Did the GBIF points look similar to the local CSV points from Assignment 01? Why might GBIF records look different?
#
# **Your answer:** The points look similar as in they are a similar range but overall different. This is because we are only asking GBIF to grab 100 points from the records, and besides filtering for points with lat and long and the species, we arent asking for specific points. The csv is presumably points from a specific paper or project, and out of all the occurances possible on GBIF it is possible that a new 100 is grabbed each time.
#
# **Question 3:** What is one reason it is useful to count records before downloading or mapping them?
#
# **Your answer:** It is useful to know so you have an idea of how many records are availbe to be fetched, and so if you are mapping multiple species, you are pulling occurance data from species with similar record counts as opposed to a speies with a high record count verusus a low one, which could skew the range depicted on the map if occurance records available are too low.

# %% [markdown]
# ## 23. Submit your work
#
# Before submitting, make sure you have run the notebook from top to bottom and answered the written questions.
#
# Commit and push your completed notebook to your class GitHub repository.
#
# Open a terminal window and run these commands to add, commit, and push your notebook:
#
# ```
# # Go to the labs directory in the course repo
# cd ~/BIO597-SpatialBiodiversity/docs/assignments
#
# # Add your changed lab
# git add Assignment-02-pygbif.ipynb
# git commit -m 'Finished Assignment 02'
# git push
# ```
